# %% [markdown]
# # Exercise 1-1: Get started with JupyterLab

# %% [markdown]
# ## Get the data

# %%
import pandas as pd # Import pandas library for data manipulation and rename panda as pd
poll_url = 'http://projects.fivethirtyeight.com/general-model/president_general_polls_2016.csv' #Define the URL
polls = pd.read_csv(poll_url) # Read the CSV

# %%
polls # prints all dataframe
polls.head()  # Display the first 5 rows (the default is 5)
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
#
#   state  startdate    enddate                  pollster grade  ...  \
# 0  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+  ...
# 1  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B  ...
# 2  U.S.  11/2/2016  11/6/2016                     Ipsos    A-  ...
# 3  U.S.  11/4/2016  11/7/2016                    YouGov     B  ...
# 4  U.S.  11/3/2016  11/6/2016          Gravis Marketing    B-  ...
#
#    adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...

# %%
# Sort the DataFrame by the 'state' column
polls.sort_values('state', inplace=True) # "inplace=True" means modify the original DataFrame directly instead of returning a new DataFrame
polls.head(2) # Display the first 2 rows
# Out:
#        cycle     branch        type                        matchup  \
# 12475   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 3304    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
#
#       forecastdate    state   startdate    enddate pollster grade  ...  \
# 12475      11/8/16  Alabama  10/21/2016  11/2/2016    Ipsos    A-  ...
# 3304       11/8/16  Alabama   7/29/2016  8/18/2016    Ipsos    A-  ...
#
#        adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 12475         40.48323      53.28125              NaN               NaN
# 3304          35.64400      56.35091              NaN               NaN
#
#        multiversions                                        url  poll_id  \
# 12475            NaN  http://www.reuters.com/statesofthenation/    48213
# 3304             NaN   http://www.reuters.com/statesofthenation    44940
#
#        question_id  createddate             timestamp
# ...

# %% [markdown]
# ## Use Tab completion and tooltips

# %%
# Sort the DataFrame by the 'state' column in descending order, after that, show the top 5 rows
polls.sort_values('state', ascending=False).head()
# Out:
#       cycle     branch        type                        matchup  \
# 5595   2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 6453   2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 9752   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 2788   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 9761   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#      forecastdate    state   startdate     enddate                 pollster  \
# 5595      11/8/16  Wyoming  10/24/2016  10/30/2016             SurveyMonkey
# 6453      11/8/16  Wyoming   9/27/2016   10/3/2016  Google Consumer Surveys
# 9752      11/8/16  Wyoming  10/25/2016  10/31/2016             SurveyMonkey
# 2788      11/8/16  Wyoming   8/24/2016   8/30/2016  Google Consumer Surveys
# 9761      11/8/16  Wyoming  10/26/2016   11/1/2016             SurveyMonkey
#
#      grade  ...  adjpoll_clinton adjpoll_trump  adjpoll_johnson  \
# ...

# %% [markdown]
# ## Clean the data

# %% [markdown]
# ### Keep only the rows with "now-cast" in the type column

# %%
polls = polls.query('type=="now-cast"')  # keep only the rows where 'type' is "now-cast"  
polls.head() # Display the first 5 rows (the default is 5)
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7628   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6238   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7142   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6225   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state   startdate     enddate                 pollster grade  ...  \
# 7434  Alabama   7/29/2016   8/18/2016                    Ipsos    A-  ...
# 7628  Alabama   8/10/2016   8/16/2016  Google Consumer Surveys     B  ...
# 6238  Alabama  10/10/2016  10/14/2016  Google Consumer Surveys     B  ...
# 7142  Alabama    9/7/2016   9/13/2016  Google Consumer Surveys     B  ...
# 6225  Alabama  10/18/2016  10/26/2016             SurveyMonkey    C-  ...
#
# ...

# %% [markdown]
# ### Rename voting columns

# %%
# rename 'rawpoll_clinton' to 'Clinton_pct'
# rename 'rawpoll_trump' to 'Trump_pct'
polls.rename(columns={'rawpoll_clinton':'Clinton_pct',
                      'rawpoll_trump':'Trump_pct'},inplace=True)
polls.head() # Display the first 5 rows (the default is 5)
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7628   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6238   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7142   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6225   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state   startdate     enddate                 pollster grade  ...  \
# 7434  Alabama   7/29/2016   8/18/2016                    Ipsos    A-  ...
# 7628  Alabama   8/10/2016   8/16/2016  Google Consumer Surveys     B  ...
# 6238  Alabama  10/10/2016  10/14/2016  Google Consumer Surveys     B  ...
# 7142  Alabama    9/7/2016   9/13/2016  Google Consumer Surveys     B  ...
# 6225  Alabama  10/18/2016  10/26/2016             SurveyMonkey    C-  ...
#
# ...

# %% [markdown]
# ### Convert date columns to datetime objects

# %%
date_cols = ["startdate","enddate"]   # Define a list of columns "startdate" and "enddate"
polls[date_cols] = polls[date_cols].apply(pd.to_datetime) # convert these two columns to datetime format 
polls.head() # Display the first 5 rows (the default is 5)
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7628   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6238   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7142   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6225   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state  startdate    enddate                 pollster grade  ...  \
# 7434  Alabama 2016-07-29 2016-08-18                    Ipsos    A-  ...
# 7628  Alabama 2016-08-10 2016-08-16  Google Consumer Surveys     B  ...
# 6238  Alabama 2016-10-10 2016-10-14  Google Consumer Surveys     B  ...
# 7142  Alabama 2016-09-07 2016-09-13  Google Consumer Surveys     B  ...
# 6225  Alabama 2016-10-18 2016-10-26             SurveyMonkey    C-  ...
#
# ...

# %% [markdown]
# ### Try two plots

# %%
# draw a line chart
polls.plot.line(x='enddate',y=['Clinton_pct','Trump_pct'])  # x-axis = enddate, y-axis = 'Clinton_pct' and 'Trump_pct'
# Out:
# <Axes: xlabel='enddate'>

# %%
# %%time
(polls.query('state == "U.S."')     # keep only the rows where 'state' is "U.S."  
    .plot(x='enddate',y=['Clinton_pct','Trump_pct']))  # draw a line chart

# %%
# lists all variables
# %whos

# %%
# check the data type of 'polls'
type(polls)

# %% [markdown]
# ## Did you use a language model?

# %% [markdown]
# ### Ans: Yes, it helps me explain code and errors. I will paste a screenshot of the error message and ask how to fix it.

# %% [markdown]
# ## What did you do to verify that your code worked as expected?

# %% [markdown]
# ### Ans: Run it and see if there is an error.
